# %%
import xarray as xr

ds = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/Climate_Downscaling/larger_alps/grid_search/tasmean/AdaBoostRegressor_tasmean_ztuvq_500_850_mslpt2_dem_sa_doy.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1826, y: 103, x: 125)
# Coordinates:
#   * time     (time) datetime64[ns] 2016-01-01 2016-01-02 ... 2020-12-30
#   * y        (y) float64 50.52 50.45 50.37 50.3 50.23 ... 43.27 43.2 43.13 43.05
#   * x        (x) float64 3.715 3.822 3.93 4.038 ... 16.75 16.85 16.96 17.07
# Data variables:
#     tasmean  (time, y, x) float64 dask.array<chunksize=(1826, 103, 125), meta=np.ndarray>
