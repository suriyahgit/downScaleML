# %%
import xarray as xr

# %%
ds = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/02_Original_Climate_Data/CERRA/")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 2928, y: 1069, x: 1069)
# Coordinates:
#   * time        (time) datetime64[ns] 2000-01-01 ... 2000-12-31T21:00:00
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  (time) datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     sp          (time, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             eswi
#     GRIB_centreDescription:  Norrkoping
#     GRIB_subCentre:          255
#     Conventions:             CF-1.7
#     institution:             Norrkoping
#     history:                 2023-11-30T14:33 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
print(ds.step)
# Out:
# <xarray.DataArray 'step' ()>
# [1 values with dtype=timedelta64[ns]]
# Coordinates:
#     step     timedelta64[ns] ...
#     surface  float64 ...
# Attributes:
#     long_name:      time since forecast_reference_time
#     standard_name:  forecast_period

# %%
ds1 = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/02_Original_Climate_Data/CERRA/2m_temperature/CERRA_2m_temperature_1985.nc")

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 2920, y: 1069, x: 1069)
# Coordinates:
#   * time               (time) datetime64[ns] 1985-01-01 ... 1985-12-31T21:00:00
#     step               timedelta64[ns] ...
#     heightAboveGround  float64 ...
#     latitude           (y, x) float64 ...
#     longitude          (y, x) float64 ...
#     valid_time         (time) datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                (time, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             eswi
#     GRIB_centreDescription:  Norrkoping
#     GRIB_subCentre:          255
#     Conventions:             CF-1.7
#     institution:             Norrkoping
#     history:                 2023-07-09T10:56 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
ds1.valid_time
# Out:
# <xarray.DataArray 'valid_time' (time: 2920)>
# [2920 values with dtype=datetime64[ns]]
# Coordinates:
#   * time               (time) datetime64[ns] 1985-01-01 ... 1985-12-31T21:00:00
#     step               timedelta64[ns] ...
#     heightAboveGround  float64 ...
#     valid_time         (time) datetime64[ns] ...
# Attributes:
#     standard_name:  time
#     long_name:      time
