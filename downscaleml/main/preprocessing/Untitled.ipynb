# %%
import xarray as xr

ds = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/02_Original_Climate_Data/CERRA/total_precipitation_analysis/")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 365, y: 1069, x: 1069)
# Coordinates:
#   * time        (time) datetime64[ns] 1985-01-01T06:00:00 ... 1985-12-31T06:0...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  (time) datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     tp          (time, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             lfpw
#     GRIB_centreDescription:  French Weather Service - Toulouse
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             French Weather Service - Toulouse
#     history:                 2023-07-09T09:25 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
import xarray as xr

ds = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/Climate_Downscaling/hydroModelDownscale/REANALYSIS/ERA5/2m_temperature/ERA5_2m_temperature_1981_2020.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14610, lon: 161, lat: 96)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-01-01 1981-01-02 ... 2020-12-31
#   * lon      (lon) float64 5.084 5.151 5.218 5.285 ... 15.62 15.69 15.76 15.82
#   * lat      (lat) float64 43.62 43.69 43.75 43.82 ... 49.8 49.86 49.93 50.0
# Data variables:
#     t2m      (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Fri Dec 08 14:07:51 2023: cdo -O -s -remapbil,/mnt/CEPH_PRO...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...

# %%
import xarray as xr

ds = xr.open_dataset("/mnt/CEPH_PROJECTS/InterTwin/Climate_Downscaling/hydroModelDownscale/DEM/interTwin_dem.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 161, lat: 96)
# Coordinates:
#   * lon      (lon) float64 5.084 5.151 5.218 5.285 ... 15.62 15.69 15.76 15.82
#   * lat      (lat) float64 43.62 43.69 43.75 43.82 ... 49.8 49.86 49.93 50.0
# Data variables:
#     Band1    (lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Wed Dec 13 12:38:41 2023: cdo remapbil,/mnt/CEPH_PROJECTS/I...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...

# %%
from ecmwfapi import ECMWFService

server = ECMWFService("mars")
server.execute(
    {
    "class": "od",
    "date": "20150101",
    "expver": "1",
    "levtype": "sfc",
    "param": "167.128",
    "step": "0/to/240/by/12",
    "stream": "oper",
    "time": "00",
    "type": "fc"
    },
    "target.grib")
# Out:
# 2024-02-05 14:03:17 ECMWF API python library 1.6.3
# 2024-02-05 14:03:17 ECMWF API at https://api.ecmwf.int/v1
# 2024-02-05 14:03:18 Welcome Andrea Manzi
# 2024-02-05 14:03:18 In case of problems, please check https://confluence.ecmwf.int/display/WEBAPI/Web+API+FAQ or contact servicedesk@ecmwf.int
# 2024-02-05 14:03:18 Request submitted
# 2024-02-05 14:03:18 Request id: 65c0dc969ff6ee45563b2f59
# 2024-02-05 14:03:18 Request is submitted
# 2024-02-05 14:03:19 Request is queued
# 2024-02-05 14:03:25 Request is active
# 2024-02-05 14:04:01 Calling 'nice mars /tmp/20240205-1300/df/tmp-_mars-hAsUUO.req'
# 2024-02-05 14:04:01 Forcing MIR_CACHE_PATH=/data/ec_coeff
# 2024-02-05 14:04:01 mars - WARN -
# 2024-02-05 14:04:01 mars - WARN -
# 2024-02-05 14:04:01 MIR environment variables:
# 2024-02-05 14:04:01 MIR_CACHE_PATH=/data/ec_coeff
# 2024-02-05 14:04:01 MIR_LSM_NAMED=1km.climate.v013
# 2024-02-05 14:04:01 Using MARS binary: /usr/local/apps/mars/versions/6.33.16.2/bin/mars.bin
# ...
